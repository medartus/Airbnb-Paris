# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# %%
listing = pd.read_csv("../datasets/listings/listings.csv",sep=",")
listing.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20201105041130   2020-11-05
# 1  3109  https://www.airbnb.com/rooms/3109  20201105041130   2020-11-06
# 2  4890  https://www.airbnb.com/rooms/4890  20201105041130   2020-11-05
# 3  5396  https://www.airbnb.com/rooms/5396  20201105041130   2020-11-06
# 4  7397  https://www.airbnb.com/rooms/7397  20201105041130   2020-11-05
#
#                                   name  \
# 0     Loft for 4 by Canal Saint Martin
# 1                         zen and calm
# 2  Quiet Historic & Cute  +Free Cruise
# 3       Explore the heart of old Paris
# 4     MARAIS - 2ROOMS APT - 2/4 PEOPLE
#
#                                          description  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  <b>The space</b><br />I bedroom appartment in ...
# 2  Stylish & Classic One bedroom apartment for up...
# 3  Cozy, well-appointed and graciously designed s...
# 4  VERY CONVENIENT, WITH THE BEST LOCATION !<br /...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Good restaurants<br />very close the Montparna...
# 2  Called "Paris Next Great Neighborhood" from Tr...
# 3  You are within walking distance to the Louvre,...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/09da057c-0120...     2827
# 1  https://a0.muscache.com/pictures/baeae9e2-cd53...     3631
# 2  https://a0.muscache.com/pictures/b144894f-bc55...     6792
# 3  https://a0.muscache.com/pictures/52413/f9bf76f...     7903
# 4  https://a0.muscache.com/pictures/67928287/330b...     2626
#
#                                  host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/2827  ...                        10.0
# 1  https://www.airbnb.com/users/show/3631  ...                        10.0
# 2  https://www.airbnb.com/users/show/6792  ...                        10.0
# 3  https://www.airbnb.com/users/show/7903  ...                        10.0
# 4  https://www.airbnb.com/users/show/2626  ...                        10.0
#
#   review_scores_location review_scores_value        license instant_bookable  \
# 0                   10.0                10.0            NaN                t
# 1                   10.0                10.0            NaN                f
# 2                   10.0                10.0            NaN                f
# 3                   10.0                 8.0  7510402838018                f
# 4                   10.0                10.0  7510400829623                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                             14                                          14
# 3                              1                                           1
# 4                              3                                           3
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.04
# 1                                           0              0.19
# 2                                           0              0.21
# 3                                           0              1.66
# 4                                           0              2.31
#
# [5 rows x 74 columns]

# %%
listing['calendar_updated']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 66331   NaN
# 66332   NaN
# 66333   NaN
# 66334   NaN
# 66335   NaN
# Name: calendar_updated, Length: 66336, dtype: float64

# %%
listing.groupby('room_type').id.nunique().sort_values()[::-1]
# Out:
# room_type
# Entire home/apt    58409
# Private room        7346
# Hotel room          1399
# Shared room          411
# Name: id, dtype: int64

# %%
listing.groupby('name').id.nunique().sort_values()[::-1]
# Out:
# name
# Charmant studio au coeur de Paris                    24
# Studio                                               24
# Charming flat in the heart of Paris                  20
# RARE - Gorgeous Apartment in the Haut-Marais!        20
# Appartement de charme                                17
#                                                      ..
# Marais. Coeur  Paris authentique.                     1
# Marais. Atypical apt 4 people                         1
# Marais. Appartement  à 1 ' de la Place des Vosges     1
# Marais-Saint Paul                                     1
# ! IDEAL POUR COURT SEJOUR A PARIS !                   1
# Name: id, Length: 64534, dtype: int64

# %%
listing.groupby('host_id').id.nunique().sort_values()[::-1]

# %%
listing[listing.room_type == "Shared room"]
# Out:
#              id                            listing_url       scrape_id  \
# 427      335003    https://www.airbnb.com/rooms/335003  20200911161645
# 850      566511    https://www.airbnb.com/rooms/566511  20200911161645
# 1519     850937    https://www.airbnb.com/rooms/850937  20200911161645
# 1685     959480    https://www.airbnb.com/rooms/959480  20200911161645
# 1981    1154909   https://www.airbnb.com/rooms/1154909  20200911161645
# ...         ...                                    ...             ...
# 67142  45183563  https://www.airbnb.com/rooms/45183563  20200911161645
# 67282  45255719  https://www.airbnb.com/rooms/45255719  20200911161645
# 67335  45283207  https://www.airbnb.com/rooms/45283207  20200911161645
# 67383  45305434  https://www.airbnb.com/rooms/45305434  20200911161645
# 67407  45319965  https://www.airbnb.com/rooms/45319965  20200911161645
#
#       last_scraped                                               name  \
# 427     2020-09-14  Cosy parisian loft near Le Louvre - Champs Ely...
# 850     2020-09-13                     SOFA bed in the heart of paris
# 1519    2020-09-14                 Vintage Living room Paris Bastille
# 1685    2020-09-13       Authentique Appartement PARTAGÉ - Girls Only
# 1981    2020-09-13                       Studio in the heart of Paris
# ...            ...                                                ...
# 67142   2020-09-13  Lit dans studette équipée en plein centre de P...
# 67282   2020-09-13  Little Studio @Lafayette & Haussmann Saint Lazare
# 67335   2020-09-13              Studio Pres de porte de Clignancourt;
# 67383   2020-09-14                                      Boudoir 19eme
# 67407   2020-09-14                            Beautiful flat in Paris
#
#                                              description  \
# 427    <b>The space</b><br />Typic Parisian Loft of 6...
# 850    My apartment is located in the heart the area ...
# 1519   Live with a parisian family, what a great expe...
# 1685   Attention : intimité limitée car mon lit et le...
# 1981   You are welcome to share my studio.<br />I pro...
# ...                                                  ...
# 67142  Studette entièrement équipée à Paris 8. <br />...
# 67282               Double bed, kitchen, shower, toilet.
# 67335  Bureau , Wi fi , soleil toute la journée. Quar...
# 67383  Nice and Sweet Studio in the 19eme arondisseme...
# 67407  The flat is 2 mins walking to metro station th...
#
#                                    neighborhood_overview  \
# 427                                                  NaN
# 850    For the last two decades the Marais  is one of...
# 1519   The location is great to visit all of Paris, a...
# 1685   Ce que j'aime dans mon quartier ? Le marché qu...
# 1981   You are staying in the very best part of Paris...
# ...                                                  ...
# 67142                                                NaN
# 67282                                                NaN
# 67335                                                NaN
# 67383  the 19th and the 20th arrondissement of Paris ...
# 67407                                                NaN
#
#                                              picture_url    host_id  \
# 427    https://a0.muscache.com/pictures/4207243/5f648...    1706168
# 850    https://a0.muscache.com/pictures/5d09947e-1056...    2782865
# 1519   https://a0.muscache.com/pictures/12478630/becc...    3980552
# 1685   https://a0.muscache.com/pictures/14279541/66c5...    5221729
# 1981   https://a0.muscache.com/pictures/17372174/4454...    6329419
# ...                                                  ...        ...
# 67142  https://a0.muscache.com/pictures/7c6112b0-81aa...   32175756
# 67282  https://a0.muscache.com/pictures/40bcacbf-4416...  365630252
# 67335  https://a0.muscache.com/pictures/b53e35f4-3628...    7303334
# 67383  https://a0.muscache.com/pictures/c6993989-c616...  365205104
# 67407  https://a0.muscache.com/pictures/8cb98ffe-f51b...  121907050
#
#                                           host_url  ...  \
# 427      https://www.airbnb.com/users/show/1706168  ...
# 850      https://www.airbnb.com/users/show/2782865  ...
# 1519     https://www.airbnb.com/users/show/3980552  ...
# 1685     https://www.airbnb.com/users/show/5221729  ...
# 1981     https://www.airbnb.com/users/show/6329419  ...
# ...                                            ...  ...
# 67142   https://www.airbnb.com/users/show/32175756  ...
# 67282  https://www.airbnb.com/users/show/365630252  ...
# 67335    https://www.airbnb.com/users/show/7303334  ...
# 67383  https://www.airbnb.com/users/show/365205104  ...
# 67407  https://www.airbnb.com/users/show/121907050  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 427                          10.0                   10.0                10.0
# 850                          10.0                   10.0                10.0
# 1519                         10.0                   10.0                10.0
# 1685                         10.0                   10.0                10.0
# 1981                         10.0                   10.0                10.0
# ...                           ...                    ...                 ...
# 67142                         NaN                    NaN                 NaN
# 67282                         NaN                    NaN                 NaN
# 67335                         NaN                    NaN                 NaN
# 67383                         NaN                    NaN                 NaN
# 67407                         NaN                    NaN                 NaN
#
#              license instant_bookable calculated_host_listings_count  \
# 427              NaN                f                              1
# 850              NaN                f                              1
# 1519   7510400899404                f                              1
# 1685             NaN                f                              2
# 1981             NaN                t                              1
# ...              ...              ...                            ...
# 67142            NaN                t                              1
# 67282            NaN                t                              2
# 67335            NaN                t                              1
# 67383            NaN                t                              1
# 67407            NaN                t                              1
#
#       calculated_host_listings_count_entire_homes  \
# 427                                             0
# 850                                             0
# 1519                                            0
# 1685                                            1
# 1981                                            0
# ...                                           ...
# 67142                                           0
# 67282                                           1
# 67335                                           0
# 67383                                           0
# 67407                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 427                                              0
# 850                                              0
# 1519                                             0
# 1685                                             0
# 1981                                             0
# ...                                            ...
# 67142                                            0
# 67282                                            0
# 67335                                            0
# 67383                                            0
# 67407                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 427                                             1              0.52
# 850                                             1              4.29
# 1519                                            1              1.52
# 1685                                            1              0.39
# 1981                                            1              3.04
# ...                                           ...               ...
# 67142                                           1               NaN
# 67282                                           1               NaN
# 67335                                           1               NaN
# 67383                                           1               NaN
# 67407                                           1               NaN
#
# [411 rows x 74 columns]

# %%
listing = listing[['id', 'scrape_id', 'last_scraped', 'name', 'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews']]

listing.head()
# Out:
#      id       scrape_id last_scraped                                 name  \
# 0  2577  20200822123310   2020-08-25     Loft for 4 by Canal Saint Martin
# 1  3109  20200822123310   2020-08-26                         zen and calm
# 2  4890  20200822123310   2020-08-23  Quiet Historic & Cute  +Free Cruise
# 3  5396  20200822123310   2020-08-26       Explore the heart of old Paris
# 4  7397  20200822123310   2020-08-26     MARAIS - 2ROOMS APT - 2/4 PEOPLE
#
#                   neighbourhood neighbourhood_cleansed  latitude  longitude  \
# 0                           NaN               Entrepôt  48.86993    2.36251
# 1  Paris, Île-de-France, France           Observatoire  48.83349    2.31852
# 2  Paris, Ile-de-France, France                 Temple  48.86409    2.35651
# 3  Paris, Ile-de-France, France         Hôtel-de-Ville  48.85100    2.35869
# 4                           NaN         Hôtel-de-Ville  48.85758    2.35275
#
#       property_type  calendar_updated has_availability  availability_30  \
# 0       Entire loft               NaN                t               30
# 1  Entire apartment               NaN                t               30
# 2  Entire apartment               NaN                t                7
# 3  Entire apartment               NaN                t                5
# 4  Entire apartment               NaN                t                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               60               90               365            2020-08-25
# 1               60               90               365            2020-08-26
# 2                7               27                28            2020-08-23
# 3               35               65                65            2020-08-26
# 4                7               27               285            2020-08-26
#
#    number_of_reviews
# 0                  1
# 1                  9
# 2                 22
# 3                225
# 4                268

# %%
f = open("calendar.csv", "r", encoding="utf8")
count = 0
for lines in f.read():
    print(lines)
    break
print(count)
# Out:
# l
# 0

# %%
reviews = pd.read_csv("reviews.csv",sep=",")
reviews
# Out:
#          listing_id         id        date  reviewer_id reviewer_name  \
# 0              2577  366217274  2019-01-02     28047930          Kate
# 1              3109  123127969  2016-12-27     12389804        Sophie
# 2              3109  123274144  2016-12-28     67553494         Tom'S
# 3              3109  207127433  2017-10-28     51636494      Patricia
# 4              3109  208779822  2017-11-03      4142888      Patricia
# ...             ...        ...         ...          ...           ...
# 1311476    45000002  655941699  2020-08-24    144864100       Osvaldo
# 1311477    45008073  655941464  2020-08-24     43257600         Fouad
# 1311478    45008073  656566695  2020-08-26    358787702          Adel
# 1311479    45028014  654502248  2020-08-22     66342443         Gamou
# 1311480    45028014  655283491  2020-08-23    363576845     Priscilla
#
#                                                   comments
# 0        Beautiful apartment in a really handy location...
# 1        The host canceled this reservation the day bef...
# 2        The host canceled this reservation 2 days befo...
# 3                  Tout s'est bien déroulé. Merci bien. PG
# 4        Un petit nid fouiller douillet situé dans  app...
# ...                                                    ...
# 1311476  I had a great time in Paris, no doubt the flat...
# 1311477  Merci beaucoup à Youssef pour son superbe accu...
# 1311478  Appartement parfaitement fidèle à la descripti...
# 1311479  Le logement de Mohamed est décoré avec goût et...
# 1311480  logement tres bien situé, tout à proximité (me...
#
# [1311481 rows x 6 columns]

# %%
del reviews['reviewer_name']
del reviews['comments']

reviews.head()
# Out:
#    listing_id         id        date  reviewer_id
# 0        2577  366217274  2019-01-02     28047930
# 1        3109  123127969  2016-12-27     12389804
# 2        3109  123274144  2016-12-28     67553494
# 3        3109  207127433  2017-10-28     51636494
# 4        3109  208779822  2017-11-03      4142888

# %%
calendar = pd.read_csv("calendar08.csv",sep=",")
calendar
# Out:
#           listing_id        date available    price adjusted_price  \
# 0              33210  2020-08-26         t  $129.00        $129.00
# 1              33210  2020-08-27         t  $129.00        $129.00
# 2              33210  2020-08-28         t  $129.00        $129.00
# 3              33210  2020-08-29         t  $129.00        $129.00
# 4              33210  2020-08-30         t  $129.00        $129.00
# ...              ...         ...       ...      ...            ...
# 24667027    35090044  2021-08-21         f   $42.00         $42.00
# 24667028    35090044  2021-08-22         f   $42.00         $42.00
# 24667029    35090044  2021-08-23         f   $42.00         $42.00
# 24667030    35090044  2021-08-24         f   $42.00         $42.00
# 24667031    35090044  2021-08-25         f   $42.00         $42.00
#
#           minimum_nights  maximum_nights
# 0                    4.0          1125.0
# 1                    4.0          1125.0
# 2                    4.0          1125.0
# 3                    4.0          1125.0
# 4                    4.0          1125.0
# ...                  ...             ...
# 24667027             1.0             8.0
# 24667028             1.0             8.0
# 24667029             1.0             8.0
# 24667030             1.0             8.0
# 24667031             1.0             8.0
#
# [24667032 rows x 7 columns]

# %%
calendar = calendar.sort_values(by=["listing_id", "date"])
calendar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e90714496be4> in <module>
# ----> 1 calendar = calendar.sort_values(by=["listing_id", "date"])
#       2 calendar
#
# NameError: name 'calendar' is not defined

# %%
calendar = calendar.reset_index()
calendar
# Out:
#            level_0     index  listing_id       date available    price  \
# 0                0       222        2577 2020-08-25         t  $125.00
# 1                1       223        2577 2020-08-26         t  $125.00
# 2                2       224        2577 2020-08-27         t  $125.00
# 3                3       225        2577 2020-08-28         t  $125.00
# 4                4       226        2577 2020-08-29         t  $125.00
# ...            ...       ...         ...        ...       ...      ...
# 24667027  24667027  24575645    45070724 2021-08-21         t   $67.00
# 24667028  24667028  24575646    45070724 2021-08-22         t   $67.00
# 24667029  24667029  24575647    45070724 2021-08-23         t   $67.00
# 24667030  24667030  24575648    45070724 2021-08-24         t   $67.00
# 24667031  24667031  24575649    45070724 2021-08-25         t   $67.00
#
#          adjusted_price  minimum_nights  maximum_nights
# 0               $125.00             3.0          1125.0
# 1               $125.00             3.0          1125.0
# 2               $125.00             3.0          1125.0
# 3               $125.00             3.0          1125.0
# 4               $125.00             3.0          1125.0
# ...                 ...             ...             ...
# 24667027         $67.00             1.0          1125.0
# 24667028         $67.00             1.0          1125.0
# 24667029         $67.00             1.0          1125.0
# 24667030         $67.00             1.0          1125.0
# 24667031         $67.00             1.0          1125.0
#
# [24667032 rows x 9 columns]

# %%
calendar.shape
# Out:
# (24667032, 5)

# %%
del calendar['price']
del calendar['index']
del calendar['adjusted_price']
#del calendar['minimum_nights']
#del calendar['maximum_nights']

calendar.head()
# Out:
#    listing_id       date available  minimum_nights  maximum_nights
# 0        2577 2020-08-25         t             3.0          1125.0
# 1        2577 2020-08-26         t             3.0          1125.0
# 2        2577 2020-08-27         t             3.0          1125.0
# 3        2577 2020-08-28         t             3.0          1125.0
# 4        2577 2020-08-29         t             3.0          1125.0

# %%
calendar["available"].value_counts()
# Out:
# f    17738117
# t     6928915
# Name: available, dtype: int64

# %%
df = pd.DataFrame(calendar["minimum_nights"].value_counts(sort=False))
df = df[df.index < 365] 
df.plot()

# %%
maxi = pd.DataFrame(calendar["maximum_nights"].value_counts())
maxi = maxi.reset_index()

# %%
calendar.shape[0]
# Out:
# 24667032

# %%
maxi["proportion"] = calendar["maximum_nights"]*100 / calendar.shape[0]
maxi.head()
# Out:
#     index  maximum_nights  proportion
# 0  1125.0        15892920    0.004561
# 1    30.0         1304445    0.004561
# 2    15.0          730140    0.004561
# 3     7.0          666999    0.004561
# 4    10.0          473079    0.004561

# %%
calendar.tail()
# Out:
#           listing_id        date available
# 24667027    35090044  2021-08-21         f
# 24667028    35090044  2021-08-22         f
# 24667029    35090044  2021-08-23         f
# 24667030    35090044  2021-08-24         f
# 24667031    35090044  2021-08-25         f

# %%
#data = calendar[(calendar["listing_id"] == 35090044) | (calendar["listing_id"] == 19222026) | (calendar["listing_id"] == 93287)]
data = calendar
data.shape
# Out:
# (24667032, 5)

# %%
data["year"],data["month"],data["day"] = data['date'].str.split('-',2).str
data.head()
# Out:
#    listing_id        date available  minimum_nights  maximum_nights  year  \
# 0       33210  2020-08-26         t             4.0          1125.0  2020
# 1       33210  2020-08-27         t             4.0          1125.0  2020
# 2       33210  2020-08-28         t             4.0          1125.0  2020
# 3       33210  2020-08-29         t             4.0          1125.0  2020
# 4       33210  2020-08-30         t             4.0          1125.0  2020
#
#   month day
# 0    08  26
# 1    08  27
# 2    08  28
# 3    08  29
# 4    08  30

# %%
data["available"].value_counts()
# Out:
# f    17738117
# t     6928915
# Name: available, dtype: int64

# %%
def fct(group):
    return [group.iloc[0]['date'], group.iloc[-1]['date'], group.shape[0], str(group.iloc[0]['listing_id']),  group.iloc[0]['available'],  group.iloc[0]['minimum_nights'],  group.iloc[0]['maximum_nights']]

# %%
adj_check = (data.available != data.available.shift()).cumsum()
newData = pd.DataFrame(data.groupby(['listing_id','available',adj_check], as_index=False, sort=False).apply(fct))
newData[['start','end','num_day','listing_id','available','minimum_nights','maximum_nights']] = pd.DataFrame(newData[0].to_list(), index= newData.index)
newData["start"] = pd.to_datetime(newData["start"])
newData["end"] = pd.to_datetime(newData["end"])
del newData[0]
newData
# Out:
#                                     start        end  num_day listing_id  \
# listing_id available available
# 2577       t         1         2020-08-25 2021-08-24      365       2577
# 3109       t         1         2020-08-26 2021-08-25      365       3109
# 4890       t         1         2020-08-23 2020-08-23        1       4890
#            f         2         2020-08-24 2020-08-24        1       4890
#            t         3         2020-08-25 2020-08-28        4       4890
# ...                                   ...        ...      ...        ...
# 45069732   t         171435    2020-09-23 2021-08-25      337   45069732
# 45070724   f         171436    2020-08-26 2020-08-26        1   45070724
#            t         171437    2020-08-27 2020-08-30        4   45070724
#            f         171438    2020-08-31 2020-09-03        4   45070724
#            t         171439    2020-09-04 2021-08-25      356   45070724
#
#                                available  minimum_nights  maximum_nights
# listing_id available available
# 2577       t         1                 t             3.0          1125.0
# 3109       t         1                 t             2.0            30.0
# 4890       t         1                 t             4.0           120.0
#            f         2                 f             4.0           120.0
#            t         3                 t             4.0           120.0
# ...                                  ...             ...             ...
# 45069732   t         171435            t             1.0            25.0
# 45070724   f         171436            f             1.0          1125.0
#            t         171437            t             1.0          1125.0
#            f         171438            f             1.0          1125.0
#            t         171439            t             1.0          1125.0
#
# [218237 rows x 7 columns]

# %%
newCal = calendar.set_index(['listing_id', 'date'])
newCal
# Out:
#                       available  minimum_nights  maximum_nights
# listing_id date
# 33210      2020-08-26         t             4.0          1125.0
#            2020-08-27         t             4.0          1125.0
#            2020-08-28         t             4.0          1125.0
#            2020-08-29         t             4.0          1125.0
#            2020-08-30         t             4.0          1125.0
# ...                         ...             ...             ...
# 35090044   2021-08-21         f             1.0             8.0
#            2021-08-22         f             1.0             8.0
#            2021-08-23         f             1.0             8.0
#            2021-08-24         f             1.0             8.0
#            2021-08-25         f             1.0             8.0
#
# [24667032 rows x 3 columns]

# %%
calendar[(calendar['listing_id'] == 35090044) & (calendar['date'] == '2020-08-26')]
# Out:
#           listing_id        date available  minimum_nights  maximum_nights  \
# 24666667    35090044  2020-08-26         f             1.0             8.0
#
#           year month day
# 24666667  2020    08  26

# %%
newCal.loc[33210]
# Out:
#            available  minimum_nights  maximum_nights
# date
# 2020-08-26         t             4.0          1125.0
# 2020-08-27         t             4.0          1125.0
# 2020-08-28         t             4.0          1125.0
# 2020-08-29         t             4.0          1125.0
# 2020-08-30         t             4.0          1125.0
# ...              ...             ...             ...
# 2021-08-21         t             4.0          1125.0
# 2021-08-22         t             4.0          1125.0
# 2021-08-23         t             4.0          1125.0
# 2021-08-24         t             4.0          1125.0
# 2021-08-25         t             4.0          1125.0
#
# [365 rows x 3 columns]

# %%
newData.shape #(309585, 8)
# Out:
# (218237, 7)

# %%
def label(row):
    try:
        if row['available'] == 'f':
            if row['num_day'] < row['minimum_nights'] or row['num_day'] > row['maximum_nights']:
                return 'closed > max nights'
            else:
                if row['num_day'] > 21:
                    return 'closed > 21 days'
                elif row['num_day'] > 14:
                    return 'closed > 14 days'
                elif row['num_day'] > 7:
                    return 'closed > 7 days'
                return 'closed < 7 days'
        else:
            return 'available'
    except:
        return 'error'
        
newData['label'] = newData.apply(label, axis=1)
newData
# Out:
#                                     start        end  num_day listing_id  \
# listing_id available available
# 2577       t         1         2020-08-25 2021-08-24      365       2577
# 3109       t         1         2020-08-26 2021-08-25      365       3109
# 4890       t         1         2020-08-23 2020-08-23        1       4890
#            f         2         2020-08-24 2020-08-24        1       4890
#            t         3         2020-08-25 2020-08-28        4       4890
# ...                                   ...        ...      ...        ...
# 45069732   t         171435    2020-09-23 2021-08-25      337   45069732
# 45070724   f         171436    2020-08-26 2020-08-26        1   45070724
#            t         171437    2020-08-27 2020-08-30        4   45070724
#            f         171438    2020-08-31 2020-09-03        4   45070724
#            t         171439    2020-09-04 2021-08-25      356   45070724
#
#                                available  minimum_nights  maximum_nights  \
# listing_id available available
# 2577       t         1                 t             3.0          1125.0
# 3109       t         1                 t             2.0            30.0
# 4890       t         1                 t             4.0           120.0
#            f         2                 f             4.0           120.0
#            t         3                 t             4.0           120.0
# ...                                  ...             ...             ...
# 45069732   t         171435            t             1.0            25.0
# 45070724   f         171436            f             1.0          1125.0
#            t         171437            t             1.0          1125.0
#            f         171438            f             1.0          1125.0
#            t         171439            t             1.0          1125.0
#
#                                               label
# listing_id available available
# 2577       t         1                    available
# 3109       t         1                    available
# 4890       t         1                    available
#            f         2          closed > max nights
#            t         3                    available
# ...                                             ...
# 45069732   t         171435               available
# 45070724   f         171436         closed < 7 days
#            t         171437               available
#            f         171438         closed < 7 days
#            t         171439               available
#
# [218237 rows x 8 columns]

# %%
calendar[calendar['listing_id'] == 93287]
# Out:
#        listing_id       date available  minimum_nights  maximum_nights
# 55491       93287 2020-08-23         f             3.0          1125.0
# 55492       93287 2020-08-24         f             3.0          1125.0
# 55493       93287 2020-08-25         f             3.0          1125.0
# 55494       93287 2020-08-26         f             3.0          1125.0
# 55495       93287 2020-08-27         f             3.0          1125.0
# ...           ...        ...       ...             ...             ...
# 55851       93287 2021-08-18         t             5.0          1125.0
# 55852       93287 2021-08-19         t             5.0          1125.0
# 55853       93287 2021-08-20         t             5.0          1125.0
# 55854       93287 2021-08-21         t             5.0          1125.0
# 55855       93287 2021-08-22         t             5.0          1125.0
#
# [365 rows x 5 columns]

# %%
newData[newData['listing_id'] == '93287']
# Out:
#                                     start        end  num_day listing_id  \
# listing_id available available
# 93287      f         644       2020-08-23 2020-09-04       13      93287
#            t         645       2020-09-05 2020-10-01       27      93287
#            f         646       2020-10-02 2020-10-05        4      93287
#            t         647       2020-10-06 2021-03-12      158      93287
#            f         648       2021-03-13 2021-03-19        7      93287
#            t         649       2021-03-20 2021-04-20       32      93287
#            f         650       2021-04-21 2021-04-24        4      93287
#            t         651       2021-04-25 2021-05-12       18      93287
#            f         652       2021-05-13 2021-05-17        5      93287
#            t         653       2021-05-18 2021-08-22       97      93287
#
#                                available  minimum_nights  maximum_nights  \
# listing_id available available
# 93287      f         644               f             3.0          1125.0
#            t         645               t             3.0          1125.0
#            f         646               f             3.0          1125.0
#            t         647               t             3.0          1125.0
#            f         648               f             3.0          1125.0
#            t         649               t             3.0          1125.0
#            f         650               f             3.0          1125.0
#            t         651               t             3.0          1125.0
#            f         652               f             3.0          1125.0
#            t         653               t             3.0          1125.0
#
#                                           label
# listing_id available available
# 93287      f         644        closed > 7 days
#            t         645              available
#            f         646        closed < 7 days
#            t         647              available
#            f         648        closed < 7 days
#            t         649              available
#            f         650        closed < 7 days
#            t         651              available
#            f         652        closed < 7 days
#            t         653              available

# %%
newData['label'].value_counts()*100/newData.shape[0]
# Out:
# available              40.600356
# closed > 21 days       20.854850
# closed < 7 days        18.099589
# closed > max nights    16.596636
# closed > 7 days         2.898225
# closed > 14 days        0.950343
# Name: label, dtype: float64

# %%
test = pd.DataFrame(calendar.groupby(["listing_id","minimum_nights"]).minimum_nights.nunique())

# %%
plop = pd.DataFrame(test.groupby("listing_id").minimum_nights.sum())
plop
# Out:
#             minimum_nights
# listing_id
# 2577                     1
# 3109                     1
# 4890                     1
# 5396                     1
# 7397                     1
# ...                    ...
# 45066830                 1
# 45066843                 1
# 45067450                 2
# 45069732                 1
# 45070724                 1
#
# [67579 rows x 1 columns]

# %%
plop['minimum_nights'].value_counts()
# Out:
# 1    59135
# 2     6610
# 3      978
# 4      544
# 5      282
# 6       26
# 8        2
# 7        2
# Name: minimum_nights, dtype: int64

# %%
data.set_value(9715159, 'available', 't')
data.head()
# Out:
# C:\Users\Med\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#          listing_id        date available  minimum_nights  maximum_nights  \
# 9715157  19222026.0  2020-08-26         f             3.0            30.0
# 9715158  19222026.0  2020-08-27         f             3.0            30.0
# 9715159  19222026.0  2020-08-28         t             3.0            30.0
# 9715160  19222026.0  2020-08-29         f             3.0            30.0
# 9715161  19222026.0  2020-08-30         f             3.0            30.0
#
#          year month day
# 9715157  2020    08  26
# 9715158  2020    08  27
# 9715159  2020    08  28
# 9715160  2020    08  29
# 9715161  2020    08  30

# %%
calendar["year"],calendar["month"],calendar["day"] = calendar['date'].str.split('-',2).str
calendar.head()
# Out:
#    listing_id        date available  minimum_nights  maximum_nights  year  \
# 0       33210  2020-08-26         t             4.0          1125.0  2020
# 1       33210  2020-08-27         t             4.0          1125.0  2020
# 2       33210  2020-08-28         t             4.0          1125.0  2020
# 3       33210  2020-08-29         t             4.0          1125.0  2020
# 4       33210  2020-08-30         t             4.0          1125.0  2020
#
#   month day
# 0    08  26
# 1    08  27
# 2    08  28
# 3    08  29
# 4    08  30

# %%
lastMonth = calendar[calendar["month"] == "08"][calendar["year"] == "2021"]
# Out:
# C:\Users\Med\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
lastMonth["available"].value_counts()
# Out:
# f    1154572
# t     413034
# Name: available, dtype: int64

# %%
data[data["available"] == "t"]
# Out:
#           listing_id        date available  year month day
# 24666673    35090044  2020-09-01         t  2020    09  01
# 24666674    35090044  2020-09-02         t  2020    09  02
# 24666675    35090044  2020-09-03         t  2020    09  03
# 24666676    35090044  2020-09-04         t  2020    09  04
# 24666677    35090044  2020-09-05         t  2020    09  05
# 24666678    35090044  2020-09-06         t  2020    09  06
# 24666679    35090044  2020-09-07         t  2020    09  07
# 24666680    35090044  2020-09-08         t  2020    09  08
# 24666681    35090044  2020-09-09         t  2020    09  09
# 24666682    35090044  2020-09-10         t  2020    09  10
# 24666683    35090044  2020-09-11         t  2020    09  11
# 24666684    35090044  2020-09-12         t  2020    09  12
# 24666685    35090044  2020-09-13         t  2020    09  13
# 24666686    35090044  2020-09-14         t  2020    09  14
# 24666687    35090044  2020-09-15         t  2020    09  15
# 24666688    35090044  2020-09-16         t  2020    09  16
# 24666689    35090044  2020-09-17         t  2020    09  17
# 24666690    35090044  2020-09-18         t  2020    09  18
# 24666691    35090044  2020-09-19         t  2020    09  19
# 24666692    35090044  2020-09-20         t  2020    09  20
# 24666693    35090044  2020-09-21         t  2020    09  21
# 24666694    35090044  2020-09-22         t  2020    09  22
# 24666695    35090044  2020-09-23         t  2020    09  23
# 24666696    35090044  2020-09-24         t  2020    09  24

# %%
test = pd.Series(data["available"].to_numpy(), index=data["date"])
calmap.calendarplot(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1af9e1470abf> in <module>
#       1 test = pd.Series(data["available"].to_numpy(), index=data["date"])
# ----> 2 calmap.calendarplot(test)
#
# ~\AppData\Roaming\Python\Python37\site-packages\calmap\__init__.py in calendarplot(data, how, yearlabels, yearascending, yearlabel_kws, subplot_kws, gridspec_kws, fig_kws, **kwargs)
#     311     fig_kws = fig_kws or {}
#     312
# --> 313     years = np.unique(data.index.year)
#     314     if not yearascending:
#     315         years = years[::-1]
#
# AttributeError: 'Index' object has no attribute 'year'

# %%
print(events)
# Out:
# 2015-11-28   -0.245426
# 2014-08-31    0.838652
# 2014-03-15   -0.208918
# 2015-05-28    0.674933
# 2015-07-06    2.442936
#                 ...
# 2014-02-12    0.008570
# 2015-10-27   -0.022533
# 2015-09-25   -1.012280
# 2014-10-17    0.095830
# 2014-10-25    0.768195
# Length: 500, dtype: float64

# %%
print("listing: ",listing.shape)
print("reviews: ",reviews.shape)
print("calendar: ",calendar.shape)
# Out:
# listing:  (67581, 18)
# reviews:  (1311481, 4)
# calendar:  (24667032, 3)

# %%
listing.dtypes
# Out:
# id                                int64
# scrape_id                         int64
# last_scraped                     object
# name                             object
# neighbourhood                    object
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed    float64
# latitude                        float64
# longitude                       float64
# property_type                    object
# calendar_updated                float64
# has_availability                 object
# availability_30                   int64
# availability_60                   int64
# availability_90                   int64
# availability_365                  int64
# calendar_last_scraped            object
# number_of_reviews                 int64
# dtype: object

# %%
listing.neighbourhood.unique()
# Out:
# array([nan, 'Paris, Île-de-France, France',
#        'Paris, Ile-de-France, France',
#        'Paris 11e Arrondissement, Île-de-France, France',
#        'Paris, IDF, France', 'Paris, France', 'Paris, IdF, France',
#        'Paris, 4th arrondissement, Île-de-France, France',
#        'Paris-13E-Arrondissement, Île-de-France, France',
#        'Levallois-Perret, Île-de-France, France',
#        'Paris, Île de France, France', 'Paris 5e, France',
#        'Paris 4e arrondissement, Île-de-France, France',
#        'Paris, Ile de France, France', 'Paris , Ile-de-France, France',
#        '10th arrondissement, Paris, Île-de-France, France',
#        'Paris 18e, France', 'Paris, Pigalle, France',
#        'Paris, le marais, France', 'Paris 1e, France',
#        'Boulogne-Billancourt, Île-de-France, France',
#        'PARIS, Île-de-France, France', 'Paris, Paris province, France',
#        'Paris, Ã\x8ele-de-France, France', 'Paris 2e, France',
#        'Paris 11e arrondissement, Île-de-France, France',
#        'Le Kremlin-Bicêtre, Île-de-France, France',
#        'Paris , île de France, France', 'Paris, ile de france, France',
#        'Paris, France, France',
#        'NEUILLY SUR SEINE, Île-de-France, France',
#        'PARIS 3eme, Île-de-France, France',
#        'Issy-les-Moulineaux, Île-de-France, France',
#        'Paris 1e, Île-de-France, France',
#        ' Deuil-la-Barre , Île-de-France, France',
#        'vanves, Île-de-France, France',
#        'Le Pré-Saint-Gervais, Île-de-France, France',
#        'Issy les moulineaux, Île-de-France, France',
#        'Paris-19E-Arrondissement, Île-de-France, France',
#        'París, Île-de-France, France', 'France',
#        'PARIS 02, Île-de-France, France', 'Parigi, Île-de-France, France',
#        'Paris-10E-Arrondissement, Île-de-France, France',
#        'Paris 09e, Île-de-France, France', 'Paris 10e, France',
#        'Paris 6e arrondissement, Île-de-France, France',
#        'Neuilly Sur Seine , Île-de-France, France',
#        'Bagnolet, France, France', 'Montrouge, Île-de-France, France',
#        'Saint-Mandé, Île-de-France, France',
#        'Paris 17 Batignolles-Monceau, France',
#        'Neuilly-sur-Seine, Île-de-France, France',
#        'Charenton Le Pont - limitrophe avec paris , Île-de-France, France',
#        'Paris-11E-Arrondissement, Île-de-France, France',
#        'Paris-18E-Arrondissement, Île-de-France, France',
#        'Clichy, Île-de-France, France',
#        'Paris Vincennes, Île-de-France, France', 'Paris 16e, France',
#        'Paris,  , France',
#        'Paris-5E-Arrondissement, Île-de-France, France',
#        'Paris city, Paris province, France',
#        'Paris 18e, Île-de-France, France',
#        'Gentilly, Île-de-France, France',
#        'Paris-17E-Arrondissement, Île-de-France, France',
#        'Paris 17ème, Île-de-France, France',
#        'Paris-20E-Arrondissement, Île-de-France, France',
#        'Paris 09e, France', 'Paris 11e, France',
#        'Pantin, Île-de-France, France', 'Paris, Ile de france, France',
#        'Paris 19e Arrondissement, France',
#        'Paris 18e Arrondissement, France',
#        'Boulogne-Billancourt, IDF, France',
#        'Paris-2E-Arrondissement, Île-de-France, France',
#        'Suresnes, Île-de-France, France',
#        'Nogent-sur-Marne, Île-de-France, France',
#        'Paris-3E-Arrondissement, Île-de-France, France',
#        'Paris, Montmartre, France', 'paris, Île-de-France, France',
#        'Paris, IDF bis, France', 'Paris 14e, France',
#        'Paris , Île-de-France, France',
#        'Paris-16E-Arrondissement, Île-de-France, France',
#        'Paris-12E-Arrondissement, Île-de-France, France', 'paris, France',
#        'Paris-14E-Arrondissement, IDF, France', 'Clichy, IDF, France',
#        'Paris-15E-Arrondissement, Île-de-France, France',
#        'Paris-1ER-Arrondissement, Île-de-France, France',
#        'Paris-4E-Arrondissement, Île-de-France, France',
#        'Paris, Île-de-Francs, France',
#        'Paris-3eme-Arrondissement, Île-de-France, France',
#        'Île-de-France, France', 'Arrondissement, Île-de-France, France',
#        'Paris-12E-Arrondissement, IDF, France',
#        'Paris-2E-Arrondissement, IDF, France',
#        'Paris-6E-Arrondissement, Île-de-France, France',
#        'Issy-les-Moulineaux, France',
#        'Paris-9E-Arrondissement, Île-de-France, France',
#        'Paris-14E-Arrondissement, Île-de-France, France',
#        'Ivry-sur-Seine, Île-de-France, France',
#        'Paris-8E-Arrondissement, Île-de-France, France',
#        'Issy-les-Moulineaux/Paris, Île-de-France, France',
#        'SAINT MAURICE, Île-de-France, France', 'Paris 15e, France',
#        'Paris-9E-Arrondissement, France', 'PARIS, Idf, France',
#        'Paris 8e, France', 'Vanves, Île-de-France, France',
#        'Paris 3e, France', 'Paris, 75, France',
#        'Paris 2e, Île-de-France, France',
#        'Paris 20e Arrondissement, France', 'Paris 20e, France',
#        'Paris 13e, France', 'PARIS, France, France',
#        'Paris 3e, Île-de-France, France',
#        'Paris 16e, Île-de-France, France',
#        'issy les moulineaux, France, France',
#        'Paris-7E-Arrondissement, Île-de-France, France',
#        'París, Isla de Francia, France',
#        'Paris 1er Arrondissement, Île-de-France, France',
#        'Paris 13e Arrondissement, France', 'Paris 4e, France',
#        'Vincennes, Île-de-France, France',
#        'Les Lilas, Île-de-France, France',
#        'Paris 20e, Île-de-France, France',
#        'Paris 3e Arrondissement, France',
#        'Paris 16e Arrondissement, France',
#        'Paris, Île-de-France, FR, Paris, France',
#        'Paris 15e Arrondissement, France',
#        'PARIS , Île-de-France, France', '巴黎, 法兰西岛, France',
#        'Paris 11e, Île-de-France, France', 'Paris 9e, France',
#        'Saint-Ouen, Île-de-France, France',
#        'Paris 4e, Île-de-France, France',
#        'Paris, Île-de-France, FR, île de France, France',
#        'Charenton-le-Pont, Île-de-France, France',
#        'Paris 8e, Île-de-France, France',
#        'Paris 12e Arrondissement, Île-de-France, France',
#        'Paris 11e, 75, France',
#        'Paris 15e Arrondissement, Île-de-France, France',
#        'Paris 7e, France', 'Paris, IF, France', 'Paris 10, France',
#        'Paris-12E-Arrondissement, France',
#        'Paris-3E-Arrondissement, France', 'Paris, 75015, France',
#        '., Paris, France', '., France', 'Paris, ., France',
#        'paris, Grand Est, France',
#        'Paris 2e Arrondissement, Île-de-France, France',
#        'Paris 9e Arrondissement, France',
#        'Paris 5e Arrondissement, France',
#        'Paris 14e Arrondissement, France',
#        'Paris 18e Arrondissement, Île-de-France, France',
#        'Paris 3e Arrondissement, Île-de-France, France',
#        'Paris 17e Arrondissement, Île-de-France, France',
#        'Paris-17E-Arrondissement, France', 'Île-de-France, Paris, France',
#        '.Champs-Elysées, PARIS, France',
#        'Aubervilliers, Île-de-France, France',
#        'Paris 14e, Île-de-France, France',
#        'Paris-6E-Arrondissement, France',
#        '9th District, Paris, Paris, France', 'Paris , France',
#        'Paris 5e Arrondissement, Île-de-France, France',
#        'Paris 11e Arrondissement, France', 'Paris, ile de France, France',
#        'Paris 13e Arrondissement, Île-de-France, France',
#        'Boulogne-Billancourt, France',
#        'PARIS, Nouvelle-Aquitaine, France',
#        'Paris 7e Arrondissement, France', 'Paris, Occitanie, France',
#        'Saint-Maurice, Île-de-France, France', 'Paris, *, France',
#        'Paris , ile de france, France',
#        'Fontenay-sous-Bois, Île-de-France, France',
#        'Paris, .Paris, France', 'Paris 17e, France',
#        'Paris 09e, 75, France', 'Paris, Île-de-France Region, France',
#        'Paris , Ile de France, France',
#        'Paris 20e Arrondissement, Île-de-France, France',
#        'Paris 7e Arrondissement, Île-de-France, France',
#        'Malakoff, Île-de-France, France', 'Paris 05 Panthéon, France',
#        'Paris, Sélectionnez la région, France', 'PARIS , France',
#        'Paris Centre, Île-de-France, France',
#        'Paris, ile-de-france, France', 'Paris-15E-Arrondissement, France',
#        'Paris , Paris, France', '-, Paris, France',
#        'PARIS, FRANCE, France', 'PARIS, Île-de-France Region, France',
#        'Paris 17e, Île-de-France, France', 'Paris 19e, France',
#        'Paris 8e Arrondissement, France', 'Paris 13 Gobelins, France',
#        'SOULAC SUR MER, France', 'Paris 6e, France',
#        'Bagnolet, Île-de-France, France', 'paris, 75, France',
#        'PARIS, 75, France', 'PAris, 75, France',
#        'Paris 14 Observatoire, Île-de-France, France',
#        'Paris 12e, France', 'Paris 5, France',
#        'Paris 2e Arrondissement, France', 'Paris 09, France',
#        'Paris 4e Arrondissement, Île-de-France, France', 'pairs, France',
#        "Sénas, Provence-Alpes-Côte d'Azur, France",
#        'PARIS, Paris, France', 'Neuilly-sur-seine, Île-de-France, France',
#        'Paris 19e Arrondissement, Île-de-France, France',
#        'Paris 5e, Île-de-France, France', 'Paris 11, France',
#        'Paris 14e, 14, France', 'Paris 07, France',
#        'Paris 14 Observatoire, France',
#        'Paris 10e Arrondissement, France', 'Paris 11e, Paris, France',
#        'Paris 15, France', 'Paris 19e, 75, France',
#        'Paris 6e, Île-de-France, France',
#        'Paris 04, Île-de-France, France', 'Vincennes, France',
#        'Paris 20e Arrondissement, Paris, France', 'Paris 11, 75, France',
#        'Charenton-Le-Pont, Île-de-France, France',
#        'Paris 19e Arrondissement, 75, France', 'Paris 15, 75, France',
#        'Paris 10e, Île-de-France, France',
#        'Paris 02, Ile de France, France', 'Paris, 75011, France',
#        'Paris, 75014, France', 'Paris 20 Ménilmontant, France',
#        'Paris 09 Opéra, France', 'Paris 18 Buttes-Montmartre, France',
#        'Paris 18e, Ile-de-France, France',
#        'Paris 11e, Ile-de-France, France',
#        'Paris 4e Arrondissement, France',
#        'Paris 12e, Ile de France, France',
#        'Paris 15e arrondissement, France', 'Paris 03 Temple, France',
#        'Paris 07 Palais-Bourbon, France',
#        'Levallois- Perret, Île-de-France, France',
#        'Paris 11 Popincourt, France', 'Paris 02 Bourse, France',
#        'Paris 20e, Paris, France', 'Paris-2E-Arrondissement, France',
#        'Paris 12e, 75, France', 'Paris 04, Paris, France',
#        'Charenton-le-Pont, France', 'Mbalmayo , Île-de-France, Cameroon',
#        'Paris 14e Arrondissement, Île-de-France, France',
#        'Paris 16 Passy, France', 'Joinville-le-Pont, IDF, France',
#        'Paris 14e, Paris, France', 'Paris 1e, Paris, France',
#        'PARIS, France', 'Paris 12 Reuilly, France',
#        'Paris, île de France, France', 'Paris 6e Arrondissement, France',
#        'Paris, paris, France', 'paris, 75011, France',
#        'Paris 04 Hôtel-de-Ville, France', 'Paris 06 Luxembourg, France',
#        'Paris 10 Entrepôt, France', 'Vincennes, IDF, France',
#        'Paris 16e Arrondissement, Île-de-France, France',
#        'Montreuil, Île-de-France, France',
#        'Joinville-le-Pont, Île-de-France, France', 'Paris , 75, France',
#        'Paris 18, France', 'Levallois Perret, Île-de-France, France',
#        'Neuilly-sur-Seine, France', 'Paris 12e Arrondissement, France',
#        'Clichy , Île-de-France, France', 'Levallois-Perret, France',
#        'Paris 14, Ile-de-France, France'], dtype=object)

# %%
listing.neighbourhood_cleansed.unique()
# Out:
# array(['Entrepôt', 'Observatoire', 'Temple', 'Hôtel-de-Ville', 'Opéra',
#        'Louvre', 'Popincourt', 'Buttes-Montmartre', 'Élysée', 'Gobelins',
#        'Luxembourg', 'Buttes-Chaumont', 'Panthéon', 'Palais-Bourbon',
#        'Reuilly', 'Bourse', 'Ménilmontant', 'Vaugirard',
#        'Batignolles-Monceau', 'Passy'], dtype=object)

# %%
 df = pd.DataFrame({'user' : ['A', 'A', 'A', 'B', 'B', 'B','B'],
              'location' : ['house','house','gym','gym','shop','gym','gym'], 
              'duration':[10,5,5,4,10,4,6]})

# %%
adj_check = (df.location != df.location.shift()).cumsum()
df.groupby(['user', 'location', adj_check], as_index=False, sort=False)['duration'].sum()
# Out:
#   user location  duration
# 0    A    house        15
# 1    A      gym         5
# 2    B      gym         4
# 3    B     shop        10
# 4    B      gym        10
